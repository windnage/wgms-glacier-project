# %% [markdown]
# # Clean GLIMS Regions
# Author: Ann Windnagel
#
# Date: 3/10/19
#
# The glacier outlines in the GLIMS database are multitemporal, so each glacier has many entries. For the analysis to find the largest glaciers in the world, need to go with the latest glacier entry.

# %% [markdown]
# ## Import Packages

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

import earthpy as et

# set working dir
os.chdir(os.path.join(et.io.HOME, "git/wgms-glacier-project"))

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import scripts.wgms_scripts as ws

# %% [markdown]
# ## Clean Region 1 - Alaska

# %%
# Open GLIMS region 1 - Alaska
glims_region_1_fp = "data/glims/processed/glims_region_1.shp"
glims_polygons_r1 = gpd.read_file(glims_region_1_fp)
glims_polygons_r1.head()
# Out:
#     line_type  anlys_id         glac_id           anlys_time  area  db_area  \
# 0  debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23   0.0  495.176
# 1  debris_cov   60414.0  G219795E60080N  2007-08-10T02:33:33   0.0  297.560
# 2  debris_cov   53065.0  G222829E58804N  2006-05-29T19:01:21   0.0  162.882
# 3  debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23   0.0  495.176
# 4  debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23   0.0  495.176
#
#    width  length  primeclass  min_elev  ...  rc_id        geog_area  \
# 0    0.0     0.0         4.0       0.0  ...  602.0  Various (NSIDC)
# 1    0.0     0.0         5.0       0.0  ...  602.0  Various (NSIDC)
# 2    0.0     0.0         5.0       0.0  ...  602.0  Various (NSIDC)
# 3    0.0     0.0         4.0       0.0  ...  602.0  Various (NSIDC)
# 4    0.0     0.0         4.0       0.0  ...  602.0  Various (NSIDC)
#
#                chief_affl loc_unc_x loc_unc_y glob_unc_x glob_unc_y  \
# 0  University of Colorado         0         0          0          0
# 1  University of Colorado         0         0          0          0
# 2  University of Colorado         0         0          0          0
# 3  University of Colorado         0         0          0          0
# 4  University of Colorado         0         0          0          0
#
#         submitters         analysts  \
# 0  Beedle, Matthew  Beedle, Matthew
# 1  Beedle, Matthew  Beedle, Matthew
# 2  Beedle, Matthew  Beedle, Matthew
# 3  Beedle, Matthew  Beedle, Matthew
# 4  Beedle, Matthew  Beedle, Matthew
#
#                                             geometry
# 0  POLYGON Z ((-136.675873 58.385483 0, -136.6753...
# 1  POLYGON Z ((-140.10202 59.96069 0, -140.10102 ...
# 2  POLYGON Z ((-137.260638 58.805875 0, -137.2596...
# 3  POLYGON Z ((-136.662581 58.464275 0, -136.6641...
# 4  POLYGON Z ((-136.652551 58.490007 0, -136.6538...
#
# [5 rows x 31 columns]

# %%
# Find the unique glaciers in region 1
unique_r1 = glims_polygons_r1.glac_name.unique()
unique_r1.shape
# Out:
# (1292,)

# %%
print(unique_r1[0])
# Out:
# Brady Glacier

# %%
# Look at the glacier at index 0
brady_glacier = glims_polygons_r1[glims_polygons_r1['glac_name']==unique_r1[0]]
brady_glacier
# Out:
#         line_type  anlys_id         glac_id           anlys_time     area  \
# 0      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 3      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 4      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 5      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 6      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 7      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 8      debris_cov   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
# 7867   glac_bound  409471.0  G223237E58554N  2015-07-16T00:00:00  549.286
# 31499  glac_bound  374572.0  G223237E58554N  2010-01-01T00:00:00    0.000
# 33385  glac_bound   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
#
#        db_area  width  length  primeclass  min_elev  ...  rc_id  \
# 0      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 3      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 4      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 5      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 6      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 7      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 8      495.176    0.0     0.0         4.0       0.0  ...  602.0
# 7867   549.286    0.0     0.0         0.0      12.0  ...  761.0
# 31499  512.353    0.0     0.0         0.0       0.0  ...    4.0
# 33385  495.176    0.0     0.0         4.0       0.0  ...  602.0
#
#                                                geog_area  \
# 0                                        Various (NSIDC)
# 3                                        Various (NSIDC)
# 4                                        Various (NSIDC)
# 5                                        Various (NSIDC)
# 6                                        Various (NSIDC)
# 7                                        Various (NSIDC)
# 8                                        Various (NSIDC)
# 7867   Randolph Glacier Inventory; Umbrella RC for me...
# 31499                                             Alaska
# 33385                                    Various (NSIDC)
#
#                      chief_affl loc_unc_x loc_unc_y glob_unc_x glob_unc_y  \
# 0        University of Colorado         0         0          0          0
# 3        University of Colorado         0         0          0          0
# 4        University of Colorado         0         0          0          0
# 5        University of Colorado         0         0          0          0
# 6        University of Colorado         0         0          0          0
# 7        University of Colorado         0         0          0          0
# 8        University of Colorado         0         0          0          0
# 7867   University of Washington        50        50         80         80
# 31499  University of Washington        15        15         10         10
# 33385    University of Colorado         7         7          0          0
#
#             submitters                                           analysts  \
# 0      Beedle, Matthew                                    Beedle, Matthew
# 3      Beedle, Matthew                                    Beedle, Matthew
# 4      Beedle, Matthew                                    Beedle, Matthew
# 5      Beedle, Matthew                                    Beedle, Matthew
# 6      Beedle, Matthew                                    Beedle, Matthew
# 7      Beedle, Matthew                                    Beedle, Matthew
# 8      Beedle, Matthew                                    Beedle, Matthew
# 7867    Cogley, Graham  Beedle, Matthew; Berthier, Etienne; Bolch, Tob...
# 31499  Arendt, Anthony                                       Rich, Justin
# 33385  Beedle, Matthew                                    Beedle, Matthew
#
#                                                 geometry
# 0      POLYGON Z ((-136.675873 58.385483 0, -136.6753...
# 3      POLYGON Z ((-136.662581 58.464275 0, -136.6641...
# 4      POLYGON Z ((-136.652551 58.490007 0, -136.6538...
# 5      POLYGON Z ((-136.851804 58.480757 0, -136.8528...
# 6      POLYGON Z ((-136.671894 58.488903 0, -136.6726...
# 7      POLYGON Z ((-136.618447 58.448369 0, -136.6177...
# 8      POLYGON Z ((-136.651831 58.426054 0, -136.6505...
# 7867   POLYGON Z ((-136.750981 58.738767 0, -136.7511...
# 31499  POLYGON Z ((-136.72171 58.690149 0, -136.72150...
# 33385  POLYGON Z ((-136.66853 58.35008 0, -136.66899 ...
#
# [10 rows x 31 columns]

# %%
# I think I just want the outlines that are line_type = glac_bound
brady_glacier = glims_polygons_r1[(glims_polygons_r1['glac_name'] == unique_r1[0]) & (
    glims_polygons_r1['line_type'] == 'glac_bound')]
brady_glacier
# Out:
#         line_type  anlys_id         glac_id           anlys_time     area  \
# 7867   glac_bound  409471.0  G223237E58554N  2015-07-16T00:00:00  549.286
# 31499  glac_bound  374572.0  G223237E58554N  2010-01-01T00:00:00    0.000
# 33385  glac_bound   58036.0  G223237E58554N  2006-05-25T07:48:23    0.000
#
#        db_area  width  length  primeclass  min_elev  ...  rc_id  \
# 7867   549.286    0.0     0.0         0.0      12.0  ...  761.0
# 31499  512.353    0.0     0.0         0.0       0.0  ...    4.0
# 33385  495.176    0.0     0.0         4.0       0.0  ...  602.0
#
#                                                geog_area  \
# 7867   Randolph Glacier Inventory; Umbrella RC for me...
# 31499                                             Alaska
# 33385                                    Various (NSIDC)
#
#                      chief_affl loc_unc_x loc_unc_y glob_unc_x glob_unc_y  \
# 7867   University of Washington        50        50         80         80
# 31499  University of Washington        15        15         10         10
# 33385    University of Colorado         7         7          0          0
#
#             submitters                                           analysts  \
# 7867    Cogley, Graham  Beedle, Matthew; Berthier, Etienne; Bolch, Tob...
# 31499  Arendt, Anthony                                       Rich, Justin
# 33385  Beedle, Matthew                                    Beedle, Matthew
#
#                                                 geometry
# 7867   POLYGON Z ((-136.750981 58.738767 0, -136.7511...
# 31499  POLYGON Z ((-136.72171 58.690149 0, -136.72150...
# 33385  POLYGON Z ((-136.66853 58.35008 0, -136.66899 ...
#
# [3 rows x 31 columns]

# %%
# Get the latest glacier outline
brady_glacier_latest = brady_glacier['anlys_time'].max()
brady_glacier_latest
# Out:
# '2015-07-16T00:00:00'
